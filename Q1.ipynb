# %%
from pyspark.sql.functions import lit

# %%
data = [("Somwwrita", "De", "Kolkata", "38"),("Subhadeep", "Tarafdar","Kolkata", 37)]

df1 = spark.createDataFrame(data, ["firstname", "lastname", "city", "age"])
display(df1)

# %%
data=[("Madhumita", "De", "Kolkata")]

df2 =  spark.createDataFrame(data, ["firstname", "lastname", "city"])
display(df2)

# %%
df1.unionByName(df2.withColumn("age", lit(None))).display()
