# %%
a= [1,2,3,4,5]
b=[6,7,8,9,10,11,12,13,14]
l=[]
i=0
diff = [{len(a)-len(b): a} if len(a)>len(b) else {len(b)-len(a): b}  if len(b)>len(a) else  {0:[]} ]
add_len =min(len(a), len(b))


print(add_len)
print(diff)


while i<add_len:
    l.append(a[i]+b[i])
    i+=1

for i in diff:
    for k,v in i.items():
        l.extend(v[k+1:-1])


print(l)

# %%
a= [1,2,3,4,5]
b=[6,7,8,9,10,11,12,13,14]
l=[]
i=0

index_a =[k for k,v in enumerate(a)]
index_b =[k for k,v in enumerate(b)]
print(index_a,index_b)

while i<min(len(a), len(b)):
    l.append(a[i]+b[i])
    i+=1

for i in range(max(len(a), len(b))):
    if i not in index_a:
        l.append(b[i])
    elif i not in index_b:
        l.append(a[i])
print(l)
