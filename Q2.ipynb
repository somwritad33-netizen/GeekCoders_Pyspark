# %%
from pyspark.sql.functions import split

# %%
df  = spark.createDataFrame([(1, 'Somwrita De'), (2, 'Subhadeep Tarafdar'), (3, "Madhumita De")], ["id", "name"])

display(df)

# %%
df1 = df\
.withColumn("fname", split("name", " ")[0])\
.withColumn("lname", split("name", " ")[1])


df1.display()
